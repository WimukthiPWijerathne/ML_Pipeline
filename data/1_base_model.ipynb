# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
                                classification_report,
                                confusion_matrix,
                                roc_auc_score,
                                roc_curve,
                                precision_recall_curve,
                                f1_score,
                                precission_score,
                                recall_score

                            )
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       6 from sklearn.ensemble import RandomForestClassifier
#       7 from sklearn.linear_model import LogisticRegression
# ----> 8 from sklearn.metrics import (
#       9                                 classification_report,
#      10                                 confusion_matrix,
#      11                                 roc_auc_score,
#      12                                 roc_curve,
#      13                                 precision_recall_curve,
#      14                                 f1_score,
#      15                                 precision_score,
#      16                                 recall_score
#      17
#      18                             )
#      19 warnings.filterwarnings('ignore')
#
# ImportError: cannot import name 'precission_score' from 'sklearn.metrics' (d:\installation\anaconda\envs\myenv\Lib\site-packages\sklearn\metrics\__init__.py)
